# %%
data_file = "Datasets/Speeches/independence_english.txt"

# %%
def load_file(file_name):
    f = open(file_name,"r")
    content = f.read()
    f.close()
    return content

# %%
training_data = '''Hello Hello World World'''

# %%
def createTable(text,k=3):
    text=text.lower()
    T={}
    for i in range(len(text)-k):
        X=text[i:i+k]
        Y=text[i+k]
        if X in T:
            if Y in T[X]:
                T[X][Y]+=1
            else:
                T[X][Y]=1
        else:
            T[X]={Y:1}
    return T

# %%
createTable(training_data)
# Out:
# {'hel': {'l': 2},
#  'ell': {'o': 2},
#  'llo': {' ': 2},
#  'lo ': {'h': 1, 'w': 1},
#  'o h': {'e': 1},
#  ' he': {'l': 1},
#  'o w': {'o': 1},
#  ' wo': {'r': 2},
#  'wor': {'l': 2},
#  'orl': {'d': 2},
#  'rld': {' ': 1},
#  'ld ': {'w': 1},
#  'd w': {'o': 1}}

# %%
def probTable(T):
    for key in T:
        total=sum(T[key].values())
        for ikey in T[key]:
            T[key][ikey]=T[key][ikey]/total
    return T

# %%
model = probTable(createTable(training_data))

# %%
import numpy as np

# %%
def sampleNext(ctx,inp):
    inp = inp[-3:]
    if inp in ctx:
        #return max(ctx[inp].items(), key = lambda x:x[1])[0]
        return np.random.choice(list(ctx[inp].keys()),p=list(ctx[inp].values()))
    else:
        return " "

# %%
sampleNext(model,"Hello Worl")
# Out:
# 'd'

# %%
model = probTable(createTable(load_file(data_file)))

# %%
createTable(load_file(data_file))
# Out:
# {'my ': {'d': 5, 'h': 1, 'o': 2},
#  'y d': {'e': 6, 'a': 1},
#  ' de': {'a': 5, 'v': 1, 'p': 1, 'm': 1},
#  'dea': {'r': 5},
#  'ear': {' ': 5, 's': 3, ',': 1, 't': 3},
#  'ar ': {'c': 5},
#  'r c': {'o': 8, 'a': 1},
#  ' co': {'u': 22, 'n': 6, 'l': 2, 'm': 5, 'r': 2},
#  'cou': {'n': 22},
#  'oun': {'t': 22, 'd': 1},
#  'unt': {'r': 22},
#  'ntr': {'y': 22},
#  'try': {'m': 7, ' ': 6, '.': 3, ',': 4, "'": 2},
#  'rym': {'e': 7},
#  'yme': {'n': 7},
#  'men': {',': 7, 't': 6, ' ': 2},
#  'en,': {'\n': 1, ' ': 6},
#  'n,\n': {'\n': 1},
#  ',\n\n': {'m': 1},
#  '\n\nm': {'a': 1, 'y': 4},
#  '\nma': {'n': 1},
#  'man': {'y': 7, 'i': 1, 'd': 1, '.': 1},
#  'any': {' ': 6, '-': 1, ',': 1},
#  'ny ': {'o': 3, 'g': 1, 'c': 1, 'r': 1},
#  'y o': {'f': 7},
#  ' of': {' ': 49},
#  'of ': {'y': 1,
#   't': 22,
#   'i': 6,
#   'c': 1,
#   'd': 1,
#   'n': 2,
#   'f': 2,
#   'o': 6,
#   'p': 4,
#   'l': 1,
#   'g': 1,
#   'm': 1,
#   's': 1},
#  'f y': {'o': 1},
#  ' yo': {'u': 2},
#  'you': {' ': 2},
#  'ou ': {'w': 1, 'm': 1},
#  'u w': {'i': 1},
#  ' wi': {'s': 2, 't': 6, 'l': 1},
#  'wis': {'h': 2},
#  'ish': {' ': 1, 'e': 1},
#  'sh ': {'m': 1, '-': 1},
#  'h m': {'a': 1},
#  ' ma': {'n': 7, 'd': 1, 's': 1},
#  'ny-': {'m': 1},
#  'y-m': {'a': 1},
#  '-ma': {'n': 1},
#  'y g': {'o': 1, 'i': 2, 'r': 2},
#  ' go': {'o': 2, 'i': 1},
#  'goo': {'d': 2},
#  'ood': {' ': 3, 's': 1},
#  'od ': {'w': 1, 'r': 2},
#  'd w': {'i': 1, 'o': 1},
#  'she': {'s': 1},
#  'hes': {' ': 1, 'e': 3},
#  'es ': {'o': 5,
#   'c': 1,
#   'h': 1,
#   'i': 1,
#   'a': 1,
#   's': 1,
#   'w': 1,
#   'd': 1,
#   't': 1},
#  's o': {'f': 17},
#  'f t': {'h': 21, 'r': 1},
#  ' th': {'e': 79, 'i': 5, 'a': 6, 'o': 5},
#  'the': {' ': 65, 's': 3, 'i': 12, 'm': 1},
#  'he ': {'h': 5,
#   'c': 15,
#   'n': 2,
#   'r': 3,
#   's': 8,
#   'a': 4,
#   't': 8,
#   'f': 6,
#   'e': 3,
#   'g': 1,
#   'l': 2,
#   'o': 1,
#   'w': 2,
#   'j': 1,
#   'p': 2,
#   'b': 1,
#   'm': 1},
#  'e h': {'o': 2, 'a': 3, 'i': 1, 'e': 2},
#  ' ho': {'l': 1, 'i': 2, 'u': 1, 'w': 2},
#  'hol': {'y': 1},
#  'oly': {' ': 1},
#  'ly ': {'f': 1, 'c': 1, 'd': 1, 'g': 1, 'r': 1},
#  'y f': {'e': 1, 'o': 3},
#  ' fe': {'s': 6},
#  'fes': {'t': 6},
#  'est': {'i': 6, ' ': 3, '.': 1},
#  'sti': {'v': 6, 'n': 1, 'c': 2, 't': 3},
#  'tiv': {'a': 6, 'i': 1, 'e': 2},
#  'iva': {'l': 6},
#  'val': {' ': 6},
#  'al ': {'o': 7, 'c': 1, 'j': 2, 'p': 1, 's': 1, 'g': 1},
#  'l o': {'f': 7, 'r': 1},
#  'f i': {'n': 6},
#  ' in': {'d': 10, ' ': 16, 'c': 1, 's': 1, 'v': 1},
#  'ind': {'e': 8, 'i': 2},
#  'nde': {'p': 8, 'n': 8, 'r': 1},
#  'dep': {'e': 8, 'r': 1},
#  'epe': {'n': 8},
#  'pen': {'d': 9, 't': 1},
#  'end': {'e': 8, ' ': 1},
#  'den': {'c': 10},
#  'enc': {'e': 10},
#  'nce': {'.': 3, ' ': 7, ',': 1},
#  'ce.': {'\n': 1, ' ': 3},
#  'e.\n': {'\n': 1},
#  '.\n\n': {'t': 3, 'o': 1, 'm': 2, '\n': 1, 'w': 1, 'i': 1},
#  '\n\nt': {'o': 1, 'h': 2},
#  '\nto': {'d': 1},
#  'tod': {'a': 6},
#  'oda': {'y': 6},
#  'day': {' ': 4, "'": 1, '.': 1, ',': 1, 's': 1},
#  'ay ': {'t': 1, 'i': 1, 'a': 1, 'f': 1},
#  'y t': {'h': 1},
#  'e c': {'o': 16, 'e': 5},
#  'ry ': {'i': 3,
#   'o': 2,
#   'w': 1,
#   'b': 1,
#   'g': 1,
#   'f': 2,
#   'd': 1,
#   'h': 2,
#   'a': 1,
#   'p': 1},
#  'y i': {'s': 3, 'n': 1},
#  ' is': {' ': 6},
#  'is ': {'f': 3,
#   'c': 1,
#   'y': 1,
#   'i': 1,
#   'l': 1,
#   's': 1,
#   't': 1,
#   'n': 1,
#   'p': 1,
#   'g': 1},
#  's f': {'u': 1, 'e': 1, 'r': 1},
#  ' fu': {'l': 3},
#  'ful': {'l': 2, 'f': 1, ' ': 1},
#  'ull': {' ': 2},
#  'll ': {'o': 1, 'r': 1, 'a': 2, 't': 2, 'p': 1},
#  'f c': {'o': 1},
#  'con': {'f': 1, 's': 5, 'o': 1},
#  'onf': {'i': 1},
#  'nfi': {'d': 1},
#  'fid': {'e': 1},
#  'ide': {'n': 2},
#  'e. ': {'t': 2, 'i': 1},
#  '. t': {'h': 4, 'o': 2},
#  's c': {'r': 2},
#  ' cr': {'o': 2},
#  'cro': {'s': 2, 'w': 1},
#  'ros': {'s': 2},
#  'oss': {'i': 1, 'e': 1},
#  'ssi': {'n': 1, 'o': 5},
#  'sin': {'g': 1},
#  'ing': {' ': 20},
#  'ng ': {'t': 10, 'i': 2, 'f': 4, 'a': 3, 'c': 1, 'u': 1, 'w': 1, 'h': 1},
#  'g t': {'h': 9, 'o': 2},
#  'e n': {'e': 3},
#  ' ne': {'w': 7, 'x': 1},
#  'new': {' ': 6, 's': 1},
#  'ew ': {'h': 1, 'c': 2, 'e': 3},
#  'w h': {'e': 1},
#  ' he': {'i': 1, 'r': 3, 'a': 3, 'l': 1},
#  'hei': {'g': 1, 'r': 12},
#  'eig': {'h': 1},
#  'igh': {'t': 6},
#  'ght': {'s': 4, ' ': 3, 'e': 4},
#  'hts': {' ': 2, ',': 1, '.': 1},
#  'ts ': {'b': 2, 'n': 1, 'w': 1, 'o': 1, 'a': 1},
#  's b': {'y': 2, 'r': 1},
#  ' by': {' ': 4},
#  'by ': {'p': 1, 'h': 1, 'g': 2},
#  'y p': {'l': 1, 'e': 1},
#  ' pl': {'o': 1, 'a': 1},
#  'plo': {'w': 1, 'i': 1},
#  'low': {'i': 1, 'e': 2},
#  'owi': {'n': 1},
#  'win': {'g': 1},
#  'e r': {'e': 2, 'a': 2},
#  ' re': {'s': 2, 'm': 1, 'g': 1, 'v': 1, 'd': 1, 'p': 2},
#  'res': {'o': 1, 't': 3, 's': 3, ' ': 1, 'p': 1},
#  'eso': {'l': 1},
#  'sol': {'v': 1, 'd': 3},
#  'olv': {'e': 2},
#  'lve': {' ': 1, 'd': 1},
#  've ': {'o': 1,
#   'i': 1,
#   'j': 1,
#   's': 2,
#   'e': 2,
#   'f': 2,
#   'a': 1,
#   'g': 1,
#   't': 1,
#   'l': 2,
#   'b': 1},
#  'e o': {'f': 7, 'u': 1, 'p': 1, 'b': 1},
#  'f d': {'r': 1},
#  ' dr': {'e': 1},
#  'dre': {'a': 1, 'n': 1, 'd': 1},
#  'rea': {'m': 1, 's': 1, 't': 2},
#  'eam': {'s': 1},
#  'ams': {' ': 1},
#  'ms ': {'w': 1},
#  's w': {'i': 2, 'e': 3, 'h': 1},
#  'wit': {'h': 6},
#  'ith': {' ': 6},
#  'th ': {'h': 1, 'a': 1, 's': 1, 'w': 1, 'l': 1, 'f': 1, 't': 1},
#  'h h': {'a': 1},
#  ' ha': {'r': 1, 's': 3, 'v': 7, 'n': 3, 'p': 3, 'd': 2},
#  'har': {'d': 1},
#  'ard': {' ': 1, ',': 2},
#  'rd ': {'w': 1},
#  ' wo': {'r': 3, 'm': 1},
#  'wor': {'k': 1, 'l': 2},
#  'ork': {'.': 1},
#  'rk.': {' ': 1},
#  'k. ': {'t': 1},
#  ' to': {'d': 5, ' ': 17},
#  "ay'": {'s': 1},
#  "y's": {' ': 3},
#  "'s ": {'s': 2, 'i': 2},
#  's s': {'u': 1, 'e': 1, 'i': 1, 'a': 1, 'p': 1},
#  ' su': {'n': 1, 'c': 1, 'f': 1},
#  'sun': {'r': 1},
#  'unr': {'i': 1},
#  'nri': {'s': 1},
#  'ris': {'e': 1, ' ': 1, 'o': 1},
#  'ise': {' ': 1, 'r': 1},
#  'se ': {'h': 3,
#   's': 1,
#   'r': 1,
#   't': 1,
#   'n': 1,
#   'b': 1,
#   'd': 1,
#   'f': 1,
#   'w': 1},
#  'has': {' ': 3},
#  'as ': {'b': 1, 'a': 1, 'w': 1, 'e': 1, 'd': 1, 't': 1, 'r': 1},
#  ' br': {'o': 2, 'a': 1},
#  'bro': {'u': 2},
#  'rou': {'g': 2, 'd': 1},
#  'oug': {'h': 2},
#  'ugh': {'t': 5},
#  'ht ': {'a': 1, 'n': 1, 't': 1},
#  't a': {' ': 1, 'n': 1, 'l': 1},
#  ' a ': {'n': 1, 'c': 3, 's': 1, 'p': 1, 'l': 1, 'h': 1},
#  'a n': {'e': 1},
#  'w c': {'o': 2},
#  'ons': {'c': 2, ' ': 3, 't': 3},
#  'nsc': {'i': 2},
#  'sci': {'o': 2},
#  'cio': {'u': 2},
#  'iou': {'s': 2},
#  'ous': {'n': 2, 'e': 1},
#  'usn': {'e': 2},
#  'sne': {'s': 2},
#  'nes': {'s': 5, ' ': 1},
#  'ess': {',': 3, 'i': 3, 'e': 2, ' ': 1, '.': 1, 'a': 1},
#  'ss,': {' ': 3},
#  's, ': {'n': 1,
#   'f': 2,
#   'm': 1,
#   'o': 2,
#   't': 2,
#   'r': 1,
#   'w': 1,
#   'h': 1,
#   'i': 1},
#  ', n': {'e': 3},
#  'w e': {'x': 2, 'n': 1},
#  ' ex': {'c': 2, 'p': 1},
#  'exc': {'i': 2},
#  'xci': {'t': 2},
#  'cit': {'e': 2},
#  'ite': {'m': 2, 'd': 1},
#  'tem': {'e': 2},
#  'eme': {'n': 2, 'm': 1},
#  'ent': {',': 3, ' ': 6, 'i': 1, 's': 1},
#  'nt,': {' ': 3},
#  't, ': {'n': 2, 'a': 1},
#  ' en': {'e': 1, 't': 1, 'v': 1},
#  'ene': {'r': 1, 's': 1},
#  'ner': {'g': 1, ' ': 1, 's': 1},
#  'erg': {'y': 1},
#  'rgy': {'.': 1},
#  'gy.': {'\n': 1},
#  'y.\n': {'\n': 4},
#  '\n\no': {'u': 1},
#  '\nou': {'r': 1},
#  'our': {' ': 14},
#  'ur ': {'l': 1, 'c': 3, 'n': 1, 'd': 3, 'h': 1, 'p': 3, 's': 1, 'j': 1},
#  'r l': {'o': 2, 'i': 4},
#  ' lo': {'v': 2, 'k': 1, 't': 1, 's': 2, 'n': 1},
#  'lov': {'e': 2},
#  'ove': {'l': 1, 'd': 1, 'r': 1},
#  'vel': {'y': 1},
#  'ely': {' ': 2},
#  'y c': {'o': 2},
#  'n, ': {'o': 1, 'w': 2, 't': 3},
#  ', o': {'n': 2, 'u': 3, 'p': 1},
#  ' on': {'c': 1, ' ': 3, 'e': 1},
#  'onc': {'e': 1},
#  'ce ': {'i': 1, 'a': 5, 'm': 1, 'f': 3, 't': 2, 'o': 3, 'p': 1},
#  'e i': {'n': 3},
#  'in ': {'1': 1, 'o': 3, 't': 9, 'f': 1, 'a': 2, 's': 1},
#  'n 1': {'2': 1},
#  ' 12': {' ': 1},
#  '12 ': {'y': 1},
#  '2 y': {'e': 1},
#  ' ye': {'a': 4},
#  'yea': {'r': 4},
#  'ars': {',': 1, '.': 1, ' ': 1},
#  'rs,': {' ': 1},
#  ', f': {'l': 1, 'o': 3},
#  ' fl': {'o': 4, 'a': 5},
#  'flo': {'w': 2, 'o': 2},
#  'owe': {'r': 4},
#  'wer': {'s': 1, ' ': 3, 'e': 1},
#  'ers': {' ': 9, 'h': 1, 'o': 1},
#  'rs ': {'o': 7, 'u': 1, 'w': 1, 's': 1},
#  'f n': {'i': 2},
#  ' ni': {'l': 3, 'g': 1},
#  'nil': {'a': 1, 'g': 1, 'k': 1},
#  'ila': {'k': 1},
#  'lak': {'u': 1},
#  'aku': {'r': 1},
#  'kur': {'i': 2},
#  'uri': {'n': 2},
#  'rin': {'y': 1, 'j': 1, 'g': 2},
#  'iny': {'a': 1},
#  'nya': {' ': 1},
#  'ya ': {'g': 1, 's': 1, 'b': 1},
#  'a g': {'r': 1},
#  ' gr': {'o': 1, 'e': 3},
#  'gro': {'w': 1},
#  'row': {' ': 1, 'd': 1},
#  'ow ': {'i': 1, 'm': 1, 'd': 1, 'o': 1, 'l': 1},
#  'w i': {'n': 1},
#  'n o': {'u': 3, 'f': 2, 'r': 1},
#  ' ou': {'r': 13},
#  'ry.': {' ': 2, '\n': 2},
#  'y. ': {'t': 1, 'i': 2},
#  'thi': {'s': 5},
#  'his': {' ': 5},
#  's y': {'e': 1},
#  'ar,': {' ': 1},
#  'r, ': {'o': 1, 't': 1, 'i': 1},
#  'on ': {'t': 2, 'o': 2, 'e': 1, 'w': 1, 'm': 1, 'p': 1},
#  'n t': {'h': 13, 'o': 2},
#  ' hi': {'l': 1, 'm': 1},
#  'hil': {'l': 1, 'd': 1},
#  'ill': {'s': 1, ' ': 1, 'e': 1, 'i': 1},
#  'lls': {' ': 1},
#  'ls ': {'o': 1},
#  'ilg': {'i': 1},
#  'lgi': {'r': 1},
#  'gir': {'i': 1},
#  'iri': {'s': 1, 'n': 1},
#  's i': {'n': 5},
#  'e s': {'o': 5, 't': 1, 'e': 5, 'p': 1, 'a': 1, 'u': 1},
#  ' so': {'u': 1, ' ': 1, 'c': 2, 'l': 3},
#  'sou': {'t': 1},
#  'out': {'h': 1},
#  'uth': {',': 1},
#  'th,': {' ': 1},
#  'h, ': {'i': 1},
#  ', i': {'t': 1, 'n': 3, ' ': 3},
#  ' it': {' ': 1, 's': 1},
#  'it ': {'i': 1},
#  't i': {'s': 1, 'n': 4},
#  's l': {'i': 1},
#  ' li': {'k': 2, 'v': 6, 'f': 2},
#  'lik': {'e': 2},
#  'ike': {' ': 2},
#  'ke ': {'o': 2, 't': 1},
#  'r n': {'i': 1},
#  'ilk': {'u': 1},
#  'lku': {'r': 1},
#  'inj': {'i': 1},
#  'nji': {' ': 1},
#  'ji ': {'f': 1},
#  'i f': {'l': 1},
#  'er ': {'l': 1, 't': 4, 'o': 2, 'a': 1},
#  'e t': {'h': 4, 'r': 8, 'o': 2},
#  'e a': {'s': 1, 'r': 7, 't': 2, 'n': 4, ' ': 1},
#  ' as': {'h': 1},
#  'ash': {'o': 1},
#  'sho': {'k': 1},
#  'hok': {' ': 1},
#  'ok ': {'c': 1, 's': 1},
#  'k c': {'h': 1},
#  ' ch': {'a': 1, 'i': 1},
#  'cha': {'k': 1, 'l': 1},
#  'hak': {'r': 1},
#  'akr': {'a': 1},
#  'kra': {' ': 1},
#  'ra ': {'o': 1, 'p': 1},
#  'a o': {'f': 1},
#  ' tr': {'i': 11},
#  'tri': {'c': 8, 'u': 1, 'b': 1, 'e': 1},
#  'ric': {'o': 8},
#  'ico': {'l': 8},
#  'col': {'o': 10},
#  'olo': {'r': 10},
#  'lor': {' ': 8, 'i': 1, 'y': 2, ',': 1},
#  'or ': {'f': 5, 'o': 2, 'c': 1, 'a': 2, 'y': 1, 't': 6},
#  'r f': {'l': 5},
#  'fla': {'g': 5},
#  'lag': {',': 1, '.': 1, ' ': 3},
#  'ag,': {' ': 1},
#  'g, ': {'i': 1},
#  'e f': {'e': 4, 'o': 4, 'a': 2, 'r': 2, 'i': 1, 'u': 1},
#  'f f': {'r': 1, 'o': 1},
#  ' fr': {'e': 3, 'a': 1, 'o': 2},
#  'fre': {'e': 3},
#  'ree': {'d': 3, 't': 1},
#  'eed': {'o': 3},
#  'edo': {'m': 3},
#  'dom': {' ': 2, ',': 1},
#  'om ': {'o': 1, 'e': 1, 't': 2, 'd': 1},
#  'm o': {'f': 1},
#  '\nmy': {' ': 4},
#  ', w': {'e': 2, 'h': 4, 'o': 1, 'i': 1},
#  ' we': {' ': 3, 'r': 1, 'n': 1, 'l': 1},
#  'we ': {'a': 4},
#  ' ar': {'e': 6, 'm': 3},
#  'are': {' ': 6, 'n': 1},
#  're ': {'c': 6, 's': 1, 'f': 1},
#  ' ce': {'l': 5},
#  'cel': {'e': 5},
#  'ele': {'b': 5},
#  'leb': {'r': 5},
#  'ebr': {'a': 5},
#  'bra': {'t': 5, 'v': 1},
#  'rat': {'i': 5},
#  'ati': {'n': 4, 'o': 1},
#  'tin': {'g': 5},
#  'ce,': {' ': 3},
#  'e, ': {'w': 3, 't': 2, 'i': 1, 'f': 1},
#  ' wh': {'e': 3, 'o': 5},
#  'whe': {'n': 3},
#  'hen': {' ': 3},
#  'en ': {'o': 1, 's': 3, 'e': 1, 'l': 1, 'f': 1, 't': 3, 'h': 1},
#  'r d': {'a': 3},
#  ' da': {'u': 3, 'y': 2},
#  'dau': {'g': 3},
#  'aug': {'h': 3},
#  'hte': {'r': 4},
#  'ter': {'s': 4, 'e': 1, 'n': 1},
#  's u': {'t': 1, 'n': 1},
#  ' ut': {'t': 1},
#  'utt': {'a': 1},
#  'tta': {'r': 1},
#  'tar': {'a': 1, 'y': 2},
#  'ara': {'k': 1, 'm': 2},
#  'rak': {'h': 1},
#  'akh': {'a': 1, 'i': 1},
#  'kha': {'n': 1},
#  'han': {'d': 1, 'g': 3},
#  'and': {',': 1, 'h': 1, ' ': 15, 'i': 2},
#  'nd,': {' ': 1},
#  'd, ': {'h': 1, 'o': 1, 'e': 1, 'd': 1, 'w': 1, 'b': 2, 't': 1},
#  ', h': {'i': 1, 'a': 1},
#  'him': {'a': 1},
#  'ima': {'c': 1},
#  'mac': {'h': 1},
#  'ach': {'a': 1},
#  'hal': {',': 1},
#  'al,': {' ': 1},
#  'l, ': {'m': 1, 'f': 1},
#  ', m': {'a': 3, 'i': 1},
#  'ani': {'p': 1},
#  'nip': {'u': 1},
#  'ipu': {'r': 1},
#  'pur': {',': 1},
#  'ur,': {' ': 1},
#  ', t': {'e': 1, 'h': 6, 'o': 3},
#  ' te': {'l': 1},
#  'tel': {'a': 1},
#  'ela': {'n': 1},
#  'lan': {'g': 1},
#  'ang': {'a': 1, 'e': 1, 'i': 2},
#  'nga': {'n': 1},
#  'gan': {'a': 1},
#  'ana': {',': 1},
#  'na,': {' ': 1},
#  'a, ': {'a': 1},
#  ', a': {'n': 1, 'm': 1, 'l': 1},
#  ' an': {'d': 16, 'y': 1},
#  'ndh': {'r': 1},
#  'dhr': {'a': 1},
#  'hra': {' ': 1},
#  'a p': {'r': 1, 'o': 1},
#  ' pr': {'a': 1, 'o': 5, 'i': 1},
#  'pra': {'d': 1},
#  'rad': {'e': 1},
#  'ade': {'s': 1, ' ': 1, 'r': 1},
#  'des': {'h': 1},
#  'esh': {' ': 1},
#  'h -': {' ': 1},
#  ' - ': {'o': 1},
#  '- o': {'u': 1},
#  'ese': {' ': 3},
#  ' st': {'a': 3},
#  'sta': {'t': 2, 'n': 1},
#  'tat': {'e': 1, 'u': 1},
#  'ate': {'s': 1},
#  'tes': {' ': 1},
#  'sse': {'d': 5},
#  'sed': {' ': 3, ',': 2, '?': 1},
#  'ed ': {'s': 1, 't': 5, 'i': 2, 'o': 2, 'f': 1, 'd': 1, 'y': 1, 'l': 1},
#  'd s': {'e': 1, 'a': 1},
#  ' se': {'v': 2, 'a': 2, 's': 2, 'e': 1, 'n': 2, 'r': 3},
#  'sev': {'e': 2},
#  'eve': {'n': 3, 'r': 4},
#  'ven': {' ': 2, 't': 1},
#  'n s': {'e': 2, 'u': 1, 't': 1},
#  'sea': {'s': 2},
#  'eas': {' ': 2, 'e': 1},
#  's a': {'n': 2, 'r': 1},
#  'nd ': {'c': 1,
#   'h': 4,
#   'r': 1,
#   'i': 1,
#   'a': 1,
#   'k': 1,
#   'd': 1,
#   'l': 1,
#   'n': 1,
#   'g': 1,
#   'f': 1,
#   't': 1,
#   's': 1},
#  'd c': {'o': 1},
#  'ori': {'n': 1},
#  'h a': {' ': 2},
#  'a c': {'o': 3},
#  'r o': {'f': 4},
#  ' ca': {'m': 1},
#  'cam': {'e': 1},
#  'ame': {' ': 2, 'n': 3, 's': 1},
#  'me ': {'b': 1, 'p': 1, 'i': 1},
#  'e b': {'a': 1, 'r': 1, 'e': 1, 'o': 1},
#  ' ba': {'c': 3, 'p': 1, 'i': 1, 'g': 2},
#  'bac': {'k': 3},
#  'ack': {'\n': 1, 'w': 2},
#  'ck\n': {'\n': 1},
#  'k\n\n': {'m': 1},
#  ' at': {' ': 2},
#  'at ': {'t': 6, 'c': 1, 'i': 1, 'm': 1, 's': 1},
#  't t': {'h': 13, 'i': 2, 'r': 1, 'o': 3},
#  'tha': {'t': 6},
#  'hat': {' ': 6},
#  ' ti': {'m': 3},
#  'tim': {'e': 3},
#  'ime': {',': 2, ' ': 1},
#  'me,': {' ': 2},
#  'n e': {'v': 2},
#  ' ev': {'e': 5, 'i': 1},
#  'ver': {'e': 3, 'y': 3, 'c': 1},
#  'ere': {'s': 3, ' ': 1, 'd': 2, 'n': 1},
#  'st ': {'t': 3, 'a': 1, 'b': 1, 'h': 1, 'e': 1},
#  'riu': {'m': 1},
#  'ium': {'p': 1},
#  'ump': {'h': 1},
#  'mph': {'s': 1},
#  'phs': {' ': 1},
#  'hs ': {'w': 1},
#  'so ': {'m': 1},
#  'o m': {'a': 1},
#  'ny,': {' ': 1},
#  'y, ': {'m': 2, 'w': 1, 'i': 1, 'o': 1, 't': 1, 'a': 1},
#  'f o': {'u': 5, 'p': 1},
#  'r h': {'e': 2},
#  'her': {'o': 3},
#  'ero': {'e': 3},
#  'roe': {'s': 3},
#  'oes': {',': 1, ' ': 1, '.': 1},
#  'es,': {' ': 5},
#  'wen': {'t': 1},
#  'nt ': {'t': 2, 'w': 1, 'm': 1, 'h': 1, 'c': 1},
#  'to ': {'t': 6, 's': 1, 'p': 4, 'b': 3, 'g': 1, 'l': 1, 'o': 1},
#  'o t': {'h': 6},
#  'e e': {'v': 3, 'n': 1, 't': 1},
#  'd h': {'o': 2, 'a': 2},
#  'hoi': {'s': 2},
#  'ois': {'t': 2},
#  'ist': {'e': 2, 'i': 1},
#  'ste': {'d': 1, 'r': 1},
#  'ted': {' ': 2, ',': 1},
#  'd t': {'h': 5, 'o': 2},
#  'ag.': {' ': 1},
#  'g. ': {'b': 1, 't': 1},
#  '. b': {'u': 1},
#  ' bu': {'t': 1},
#  'but': {' ': 1},
#  'ut ': {'i': 1},
#  'tio': {'n': 5},
#  'ion': {' ': 4, 's': 2, 'a': 4, '.': 1},
#  'om,': {' ': 1},
#  'm, ': {'i': 1},
#  ' i ': {'w': 1, 'h': 2, 'b': 1, 'a': 2},
#  'i w': {'i': 1},
#  'wil': {'l': 1},
#  'l r': {'e': 1},
#  'rem': {'e': 1},
#  'mem': {'b': 1},
#  'emb': {'e': 1},
#  'mbe': {'r': 1},
#  'ber': {' ': 1},
#  'r t': {'h': 8, 'o': 2},
#  'rib': {'a': 1},
#  'iba': {'l': 1},
#  'bal': {' ': 1},
#  'l c': {'h': 1},
#  'chi': {'l': 1},
#  'ild': {'r': 1},
#  'ldr': {'e': 1},
#  'ren': {' ': 1, 'e': 1, 't': 1},
#  'n l': {'i': 1},
#  'liv': {'i': 1, 'e': 5},
#  'ivi': {'n': 3, 't': 1},
#  'vin': {'g': 3},
#  'g i': {'n': 2},
#  'n f': {'a': 1, 'u': 1},
#  ' fa': {'r': 1, 'c': 1, 'm': 1},
#  'far': {'-': 1},
#  'ar-': {'o': 1},
#  'r-o': {'f': 1},
#  '-of': {'f': 1},
#  'off': {' ': 1},
#  'ff ': {'j': 1},
#  'f j': {'u': 1},
#  ' ju': {'n': 1, 's': 3, 'b': 1},
#  'jun': {'g': 1},
#  'ung': {'l': 1},
#  'ngl': {'e': 1},
#  'gle': {'s': 1},
#  'les': {' ': 1},
#  's h': {'a': 1},
#  'hav': {'e': 7},
#  'ave': {' ': 8},
#  'inc': {'r': 1},
#  'ncr': {'e': 1},
#  'cre': {'a': 1, 's': 1},
#  'ase': {'d': 1},
#  'e g': {'l': 1, 'a': 1},
#  ' gl': {'o': 2},
#  'glo': {'r': 2},
#  'ory': {' ': 2},
#  'ag ': {'b': 1, 'o': 1, 't': 1},
#  'g b': {'y': 1},
#  'y h': {'o': 1, 'e': 1, 'a': 2},
#  'g o': {'n': 1},
#  'st.': {'\n': 1},
#  't.\n': {'\n': 1},
#  '\n\n\n': {'m': 1},
#  'ses': {'s': 2},
#  'sio': {'n': 5},
#  'ns ': {'o': 2, 'u': 1},
#  'e l': {'o': 3, 'e': 1},
#  'lok': {' ': 1},
#  'k s': {'a': 1},
#  ' sa': {'b': 2, 'k': 1, 'c': 4},
#  'sab': {'h': 2},
#  'abh': {'a': 2},
#  'bha': {' ': 2},
#  'ha ': {'a': 1, 'h': 1},
#  'a a': {'n': 1},
#  'd r': {'a': 2, 'e': 1},
#  ' ra': {'j': 1, 'n': 2, 'i': 1},
#  'raj': {'y': 1},
#  'ajy': {'a': 1},
#  'jya': {' ': 2},
#  'a s': {'a': 1, 'e': 1},
#  'a h': {'a': 2, 'u': 1},
#  'e j': {'u': 2},
#  'jus': {'t': 3},
#  'ust': {' ': 2, 'i': 2},
#  't b': {'e': 1, 'a': 1},
#  ' be': {'e': 2, ' ': 2, 't': 1},
#  'bee': {'n': 2},
#  'een': {' ': 3},
#  'ulf': {'i': 1},
#  'lfi': {'l': 1},
#  'fil': {'l': 1},
#  'lle': {'d': 1},
#  'led': {'.': 1},
#  'ed.': {' ': 1},
#  'd. ': {'y': 1},
#  '. y': {'o': 1},
#  'u m': {'u': 1},
#  ' mu': {'s': 1},
#  'mus': {'t': 1},
#  't h': {'a': 2},
#  'see': {'n': 1},
#  'hou': {'s': 1},
#  'use': {' ': 1},
#  'ran': {' ': 1, 'k': 1},
#  'an ': {'v': 1, 'w': 1},
#  'n v': {'e': 1},
#  ' ve': {'r': 2},
#  'ery': {' ': 3, '.': 1},
#  'y w': {'e': 1},
#  'wel': {'l': 1},
#  'ell': {' ': 1},
#  'l a': {'n': 1, 'r': 1},
#  'd i': {'n': 2, 't': 1},
#  'n a': {' ': 1, 'n': 1},
#  'sen': {'s': 2},
#  'ens': {'e': 1, 'i': 1},
#  'nse': {' ': 1},
#  'f p': {'a': 1, 'o': 1, 'e': 1, 'u': 1},
#  ' pa': {'r': 5, 's': 1},
#  'par': {'l': 3, 'a': 2},
#  'arl': {'i': 3},
#  'rli': {'a': 3},
#  'lia': {'m': 3, 'n': 2},
#  'iam': {'e': 3},
#  't w': {'a': 1},
#  ' wa': {'s': 2},
#  'was': {' ': 2},
#  's e': {'n': 1},
#  'nti': {'r': 1},
#  'tir': {'e': 1},
#  'ire': {'l': 1},
#  'rel': {'y': 1},
#  'dev': {'o': 1},
#  'evo': {'t': 1, 'l': 1},
#  'vot': {'e': 1},
#  'ote': {'d': 1, 'c': 4},
#  'o s': {'o': 1},
#  'soc': {'i': 2},
#  'oci': {'a': 2},
#  'cia': {'l': 2},
#  'ial': {' ': 2},
#  'l j': {'u': 2},
#  'tic': {'e': 2},
#  'ice': {'.': 1, ' ': 8, ',': 1},
#  'o p': {'r': 4},
#  'pro': {'t': 4, 'u': 1},
#  'rot': {'e': 4},
#  'tec': {'t': 4},
#  'ect': {' ': 5},
#  'ct ': {'t': 5, 'a': 1},
#  'eir': {' ': 12},
#  'ir ': {'r': 3, 'l': 4, 'g': 1, 's': 1, 'p': 1, 'h': 1, 'm': 1},
#  'r r': {'i': 3},
#  ' ri': {'g': 3},
#  'rig': {'h': 3},
#  'ts,': {' ': 1},
#  'r p': {'a': 2, 'o': 2},
#  't m': {'a': 1, 'e': 1},
#  'mad': {'e': 1},
#  'de ': {'s': 1},
#  'e m': {'o': 1, 'e': 1},
#  ' mo': {'r': 1},
#  'mor': {'e': 1},
#  'ore': {' ': 1},
#  ' fo': {'r': 14},
#  'for': {'c': 4, ' ': 9, 't': 1},
#  'orc': {'e': 4},
#  'rce': {'f': 1, 's': 2, ',': 1},
#  'cef': {'u': 1},
#  'efu': {'l': 1},
#  'ul ': {'w': 1},
#  'l w': {'i': 1},
#  'h s': {'e': 1},
#  'nsi': {'t': 1},
#  'sit': {'i': 3},
#  'iti': {'v': 3},
#  'vit': {'y': 1},
#  'ity': {' ': 1},
#  'ty ': {'a': 1},
#  'y a': {'n': 4},
#  'd a': {'w': 1},
#  ' aw': {'a': 1},
#  'awa': {'r': 1},
#  'war': {'e': 1, 'd': 2},
#  'o b': {'e': 2, 'a': 1},
#  'be ': {'o': 1, 'a': 1},
#  ' op': {'p': 3},
#  'opp': {'r': 3},
#  'ppr': {'e': 3},
#  'pre': {'s': 3},
#  'ed,': {' ': 4},
#  ', e': {'x': 1},
#  'exp': {'l': 1},
#  'xpl': {'o': 1},
#  'loi': {'t': 1},
#  'oit': {'e': 1},
#  ', d': {'e': 1},
#  'epr': {'i': 1},
#  'pri': {'v': 1, 's': 1},
#  'riv': {'e': 1},
#  'ive': {'d': 1, ' ': 6, 's': 4},
#  'ved': {',': 1, ' ': 2},
#  'wom': {'e': 1},
#  'ome': {'n': 1},
#  'ts.': {'\n': 1},
#  's.\n': {'\n': 1},
#  '\nth': {'e': 2},
#  ' ob': {'c': 1},
#  'obc': {' ': 1},
#  'bc ': {'c': 1},
#  'c c': {'o': 1},
#  'com': {'m': 3, 'i': 2},
#  'omm': {'i': 2, 'o': 1},
#  'mmi': {'s': 2},
#  'mis': {'s': 2, 'e': 1},
#  'iss': {'i': 2, 'e': 1},
#  'n w': {'a': 1, 'h': 1},
#  's d': {'e': 1, 'u': 1},
#  'dem': {'a': 1},
#  'ema': {'n': 1},
#  'ndi': {'n': 2, 'a': 2},
#  'din': {'g': 3, 'a': 1},
#  'g f': {'o': 2, 'r': 2},
#  'r a': {' ': 1, 'l': 1, 'n': 1},
#  'nst': {'i': 3},
#  'tit': {'u': 3},
#  'itu': {'t': 3},
#  'tut': {'i': 3},
#  'uti': {'o': 4},
#  'ona': {'l': 3, 'r': 1},
#  'nal': {' ': 4},
#  'l p': {'l': 1, 'o': 1},
#  'pla': {'c': 1},
#  'lac': {'e': 1},
#  'ace': {' ': 1},
#  'r y': {'e': 1},
#  'rs.': {' ': 1},
#  's. ': {'t': 1, 'i': 1},
#  's t': {'i': 1, 'r': 1, 'o': 3, 'h': 1},
#  'e p': {'a': 2, 'r': 1, 'o': 1, 'e': 1},
#  'rie': {'d': 1, 's': 2},
#  'ied': {' ': 1},
#  ' gi': {'v': 5},
#  'giv': {'i': 2, 'e': 3},
#  'g a': {' ': 1, 'l': 1, 'n': 1},
#  ' or': {'d': 3},
#  'ord': {'e': 2, 'i': 1},
#  'rde': {'r': 2},
#  'der': {' ': 3, 's': 1},
#  'ckw': {'a': 2},
#  'kwa': {'r': 2},
#  'rd,': {' ': 2},
#  ', b': {'a': 1, 'y': 1},
#  'g c': {'o': 1},
#  'l s': {'t': 1},
#  'atu': {'s': 1},
#  'tus': {' ': 1},
#  'us ': {'t': 2},
#  't c': {'o': 2},
#  'on.': {'\n': 1},
#  'n.\n': {'\n': 1},
#  '\n\nw': {'e': 1},
#  '\nwe': {' ': 1},
#  'tho': {'s': 5},
#  'hos': {'e': 5},
#  'ose': {' ': 5},
#  'ews': {' ': 1},
#  'ws ': {'i': 1},
#  'y b': {'r': 1},
#  't n': {'e': 1},
#  'ss ': {'t': 1},
#  'ry,': {' ': 4},
#  'h w': {'h': 1},
#  'who': {'m': 1, ' ': 4},
#  'hom': {' ': 1},
#  'm e': {'v': 1},
#  'dia': {'n': 1, ' ': 1},
#  'ian': {' ': 1, 'w': 2},
#  'ho ': {'i': 1, 'h': 3},
#  'o i': {'s': 1},
#  's n': {'o': 1, 'a': 1},
#  ' no': {'t': 1},
#  'not': {' ': 1},
#  'ot ': {'i': 1, 'o': 1},
#  'cor': {'n': 2},
#  'orn': {'e': 2},
#  'rne': {'r': 2},
#  'e w': {'o': 2, 'h': 1},
#  'orl': {'d': 2},
#  'rld': {',': 1, "'": 1},
#  'ld,': {' ': 1},
#  's p': {'r': 1},
#  'oud': {' ': 1},
#  'ud ': {'o': 1},
#  'd o': {'f': 1, 'n': 2},
#  'fac': {'t': 1},
#  'act': {' ': 1},
#  'ia ': {'h': 1},
#  's r': {'e': 1},
#  'reg': {'i': 1},
#  'egi': {'s': 1},
#  'gis': {'t': 1},
#  'red': {' ': 4},
#  'its': {' ': 1},
#  ' na': {'m': 1},
#  'nam': {'e': 1},
#  "ld'": {'s': 1},
#  "d's": {' ': 1},
#  ' si': {'x': 1},
#  'six': {'t': 1},
#  'ixt': {'h': 1},
#  'xth': {' ': 1},
#  'h l': {'a': 1},
#  ' la': {'r': 1},
#  'lar': {'g': 1},
#  'arg': {'e': 1},
#  'rge': {'s': 1},
#  'ges': {'t': 1},
#  't e': {'c': 1},
#  ' ec': {'o': 1},
#  'eco': {'n': 1},
#  'ono': {'m': 1},
#  'nom': {'y': 1},
#  'omy': {'.': 1},
#  'my.': {' ': 1},
#  '. i': {'n': 1, ' ': 3},
#  'suc': {'h': 1},
#  'uch': {' ': 1},
#  'ch ': {'a': 1},
#  ' po': {'s': 2, 'l': 2, 'w': 2},
#  'pos': {'i': 2},
#  'osi': {'t': 2},
#  'env': {'i': 1},
#  'nvi': {'r': 1},
#  'vir': {'o': 1},
#  'iro': {'n': 1},
#  'ron': {'m': 1},
#  'onm': {'e': 1},
#  'nme': {'n': 1},
#  ' am': {'o': 1, ' ': 2},
#  'amo': {'n': 1},
#  'mon': {'g': 1, ' ': 1},
#  'ong': {' ': 3, '.': 1},
#  'ser': {'i': 1, 'v': 2, 'y': 1},
#  'eri': {'e': 1},
#  'ies': {' ': 3, ',': 1},
#  'nts': {' ': 1},
#  'ay.': {'\n': 1},
#  '\n\ni': {'n': 1, ' ': 1},
#  '\nin': {' ': 1},
#  'o g': {'i': 1},
#  'm t': {'o': 1, 'h': 1},
#  ' mi': {'l': 1, 's': 1},
#  'mil': {'l': 1, 'i': 3},
#  'lli': {'o': 1},
#  'lio': {'n': 1},
#  ' pe': {'o': 2, 'r': 1},
#  'peo': {'p': 2},
#  'eop': {'l': 2},
#  'opl': {'e': 2},
#  'ple': {' ': 2},
#  'le ': {'s': 1, 'o': 1},
#  ' sp': {'e': 2},
#  'spe': {'n': 2, 'c': 1},
#  'ves': {' ': 2, ',': 2},
#  'jub': {'i': 1},
#  'ubi': {'l': 1},
#  'bil': {'e': 1},
#  'ile': {'e': 1},
#  'lee': {' ': 1},
#  'ee ': {'p': 1},
#  'iso': {'n': 1},
#  'son': {'s': 1, 'n': 1},
#  ' un': {'d': 1},
#  'und': {'e': 1, 'r': 1, 'a': 1},
#  ' le': {'a': 1},
#  'lea': {'d': 1},
#  'ead': {'e': 1},
#  'rsh': {'i': 1},
#  'shi': {'p': 1},
#  'hip': {' ': 1},
#  'ip ': {'o': 1},
#  'p o': {'f': 1},
#  ' pu': {'j': 1},
#  'puj': {'y': 1},
#  'ujy': {'a': 1},
#  'a b': {'a': 3},
#  'bap': {'u': 1},
#  'apu': {'.': 1},
#  'pu.': {' ': 1},
#  'u. ': {'m': 1},
#  '. m': {'a': 1},
#  'y r': {'e': 2},
#  'rev': {'o': 1},
#  'vol': {'u': 1, 'v': 1},
#  'olu': {'t': 1},
#  'lut': {'i': 1},
#  'nar': {'y': 2},
#  'ary': {' ': 4},
#  'gre': {'a': 2, 'e': 1},
#  'eat': {' ': 2},
#  ' me': {'n': 1, 's': 1},
#  'n h': {'a': 1},
#  'nge': {'d': 1},
#  'ged': {' ': 1},
#  'ngi': {'n': 2},
#  'gin': {'g': 2},
#  'fra': {'m': 1},
#  'ram': {'e': 1, 'i': 2},
#  'mes': {' ': 1, 's': 1},
#  'd k': {'i': 1},
#  ' ki': {'s': 1},
#  'kis': {'s': 1},
#  "ry'": {'s': 2},
#  'i h': {'e': 2},
#  'hea': {'r': 3},
#  'art': {'i': 2, ' ': 1},
#  'rti': {'l': 2},
#  'til': {'y': 2},
#  'ily': {' ': 2},
#  'eet': {' ': 1},
#  'et ': {'t': 1},
#  'rav': {'e': 1},
#  ' fi': {'g': 1},
#  'fig': {'h': 1},
#  'fro': {'m': 2},
#  'rom': {' ': 2},
#  'ay,': {' ': 1},
#  'i b': {'o': 2},
#  ' bo': {'w': 2, 'u': 1},
#  'bow': {' ': 2},
#  'w m': {'y': 1},
#  ' my': {' ': 1},
#  'rt ': {'t': 1, 'i': 1},
#  ' et': {'e': 1},
#  'ete': {'r': 1},
#  'ern': {'a': 1},
#  'rna': {'l': 1},
#  'l g': {'l': 1},
#  'or,': {' ': 1},
#  'ins': {'p': 1},
#  'nsp': {'i': 1},
#  'spi': {'r': 1},
#  'pir': {'i': 1},
#  'g u': {'s': 1},
#  ' us': {' ': 1},
#  'o l': {'i': 1},
#  'd d': {'i': 2},
#  ' di': {'e': 1, 'f': 2},
#  'die': {',': 1, 'r': 3},
#  'ie,': {' ': 1},
#  'sak': {'e': 1, 'h': 1},
#  'ake': {' ': 1},
#  'arm': {'y': 3},
#  'rmy': {' ': 2, ',': 1},
#  'r s': {'o': 1, 'a': 1},
#  'old': {'i': 3},
#  'ldi': {'e': 3},
#  'ier': {'s': 3},
#  'sac': {'r': 5},
#  'acr': {'i': 4, 'e': 1},
#  'cri': {'f': 4},
#  'rif': {'i': 4},
#  'ifi': {'c': 4},
#  'fic': {'e': 4, 'u': 1},
#  'ami': {'l': 3},
#  'ili': {'t': 2, 'e': 1},
#  'lit': {'a': 2},
#  'ita': {'r': 2},
#  'ces': {' ': 1, ',': 1},
#  'd l': {'i': 2},
#  'lif': {'e': 2},
#  'ife': {',': 1, ' ': 1},
#  'fe,': {' ': 1},
#  'pol': {'i': 2},
#  'oli': {'c': 2},
#  'lic': {'e': 2},
#  'erv': {'i': 2},
#  'rvi': {'c': 2},
#  ...}
